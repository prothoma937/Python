# %%
phone_number=124
print(phone_number)
# Out:
# 124

# %%
name="Prothoma"
print(name)
# Out:
# Prothoma

# %%
age=20
height=5.6
name="ajme"
is_past= True

age=50

print(type(age),type(height),type(is_past))
print(age)
# Out:
# <class 'int'> <class 'float'> <class 'bool'>
# 50

# %% [markdown]
# Input in python

# %%
name=input("what is name")
print(name)
# Out:
# what is name40
# 40

# %%
age=input("age?")
print(age,type(age))
# Out:
# age?20
# 20 <class 'str'>

# %%
age=input("age?")
age=int(age)
print(age,type(age))
# Out:
# age?20
# 20 <class 'int'>

# %%
height=float(input("height?"))

print(height,type(height))
height=height+0.3
print(height)
# Out:
# height?10
# 10.0 <class 'float'>
# 10.3

# %% [markdown]
# operator

# %%
x=10; y=5
sum=x+y
sub=x-y
mult=x*y
div=x//y
print(sum,sub,mult,div,type(div),type(y))
# Out:
# 15 5 50 2 <class 'int'> <class 'int'>

# %%
x=10;y=3;
greater_then=x>y
grater_then_or_equal=10>=11
equal= x!=y

print(greater_then,grater_then_or_equal,equal)
# Out:
# True False True

# %% [markdown]
# Logical operator

# %%
x=10
y=-3
z=20

result=(x>y) and  (x>z)
print(result )
# Out:
# False

# %%
x=10
y=-3
z=20

result=(x>y) or  (x>z)
print(result )
# Out:
# True

# %% [markdown]
# ## Precedence
# high(/,*)
# low(-,+)
# associativity== left to right

# %%
eq=10 + 10/2 - 5*2
print(eq)
# Out:
# 5.0

# %% [markdown]
# Problem solve

# %%
inp=input()
num=inp.split()
# y=input()
# print(x,type(x))
# x=int(input())
# y=int(input())
# print(x,y)
# last_degit_of_x=x%10
# last_degit_of_y=y%10

# sum= last_degit_of_x+ last_degit_of_y
# print(sum)
# Out:
# 10 20
# ['10', '20']

# %%
inp=input()
num=inp.split()

x= int(num[0])
y=int(num[1])

last_digit_of_x=x%10
last_digit_of_y=y%10
sum= last_digit_of_x + last_digit_of_y
print(sum)
# Out:
# 12 33
# 5
