# %% [markdown]
# #tuple

# %%
#dec
tup=( 1,3,4,5)
print(tup)
# Out:
# (1, 3, 4, 5)

# %%
tup=(10,)
print(tup,type(tup))
# Out:
# (10,) <class 'tuple'>

# %%
#list
lst=[1,3,4,5,6]
print(lst,type(lst))
tup=tuple(lst)
print(tup,type(tup))
# Out:
# [1, 3, 4, 5, 6] <class 'list'>
# (1, 3, 4, 5, 6) <class 'tuple'>

# %%
#acess
tup=(10,3,4,55,59)
print(tup[4])

#slice
new_tup=tup[0:3:2]
print(new_tup)
# Out:
# 59
# (10, 4)

# %%
#immutablity
tuple=(2,34,5,5,66)
# tuple[0]=100 #immutablity
print(tuple.count(5))
print(tuple.index(5))
# Out:
# 2
# 2

# %% [markdown]
# #set
# unorder(indexing,slicing)

# %%
sett={1,2,3,444,444,22,2}
print(sett)
# Out:
# {1, 2, 3, 22, 444}

# %%
sett = {1, 2, 3, 444, 22}

if 3 in sett:
    print("3 is present")
else:
    print("not present")
# Out:
# 3 is present

# %%
sett = {1, 2, 3, 444, 22}
sett.add(100)
sett.pop()
sett.remove(444)
print(sett)
# Out:
# {2, 3, 100, 22}

# %%
#set mat method
a = {1, 2, 3, 444, 22}
b = {1, 78, 99, 444, 22,22,3}
print(a.union(b))
print(a.intersection(b))
print(a.isdisjoint(b))
print(b.issubset(a))
# Out:
# {1, 2, 3, 99, 78, 22, 444}
# {1, 3, 444, 22}
# False
# False

# %% [markdown]
# #dictionaries

# %%
dic={
    "name":"Ajme","age":20,"address":"Dhaka","num":[12333],"age":40}
dic["name"]="prothoma"
print(dic.get("age"))
# print(dic["name"])
print(dic.get("mat mark",0))
# Out:
# 40
# 0

# %%
dic={
    "name":"Ajme","age":20,"address":"Dhaka","num":[12333],"age":40}
dic.update({"mat_mark":50})
del dic["num"]
print(dic)
# Out:
# {'name': 'Ajme', 'age': 40, 'address': 'Dhaka', 'mat_mark': 50}

# %%
dic_2=dic.copy()
print(dic_2)
# Out:
# {'name': 'Ajme', 'age': 40, 'address': 'Dhaka', 'mat_mark': 50}

# %% [markdown]
# #view method

# %%
keys=dic.keys()
# print(keys)
values=dic.values()
dic["mat_mark"]=100
# print(values)
items=dic.items()
print(items)
#ITE
# for key,value in dic.items():
#   print(key,value)
# Out:
# dict_items([('name', 'Ajme'), ('age', 40), ('address', 'Dhaka'), ('mat_mark', 100)])

# %% [markdown]
# #DICTIONNARY COMPREHENSION

# %%
squre={x:x**2 for x in range(10) if x%2==0}
print(squre)
# Out:
# {0: 0, 2: 4, 4: 16, 6: 36, 8: 64}

# %%
co_ordinate=[(10,20.4),(20.9,44),(101,30)]
locations=["Dhaka","Mirpur","Purbacol"]
exact_location={co_or : loc for co_or,loc in zip(co_ordinate,locations)}
print(exact_location)
# Out:
# {(10, 20.4): 'Dhaka', (20.9, 44): 'Mirpur', (101, 30): 'Purbacol'}
