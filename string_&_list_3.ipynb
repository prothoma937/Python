# %% [markdown]
# ##string

# %%
name="Ajme"
print(name)
# Out:
# Ajme

# %%
sms="""
hi
tell me about yourself
how are you tacking them
"""
print(sms)
# Out:
#
# hi
# tell me about yourself
# how are you tacking them

# %% [markdown]
# ##indexing and slicing

# %%
str = "Hello word"
print(str[0])
# Out:
# H

# %% [markdown]
# string[str,end,step]

# %%
first_sms=sms[0:24]
print(first_sms)
# Out:
#
# hi
# tell me about yours

# %%
print(first_sms[-1])
print(first_sms[-2])
# Out:
# s
# r

# %% [markdown]
# ##string method

# %%
string= "Welcome Python to Python,ml ,ai ml ,hello ml"
process_string=string.lower()
print(process_string)
print(len(string))
#search word
print("python" in process_string)
# first index cheack
index=process_string.find("python")
print(index)

# first index cheack
last_index=process_string.rfind("python")
print(last_index)

#substring count
count=process_string.count("python")
print(count)

#replece
new_string=string.replace("ml","ai/ml")
print(new_string)g
# Out:
# welcome python to python,ml ,ai ml ,hello ml
# 44
# True
# 8
# 18
# 2
# Welcome Python to Python,ai/ml ,ai ai/ml ,hello ai/ml

# %%
string="Welcome to Python to Python,ml,ai ml,hello ml"
process_string=string.lower()
print(len(string))
print("python" in process_string )
index=process_string.find("python")
print(index)
last_index=process_string.rfind("python")
new_string=string.replace("ml","ml/ai")
print(new_string)
# Out:
# 45
# True
# 11
# Welcome to Python to Python,ml/ai,ai ml/ai,hello ml/ai

# %% [markdown]
# string split, joining ,formatted string

# %%
prompt= "What-is-Python?"
token=prompt.split("-")
print(token)

sentence= "-".join(token)
print(sentence)
# Out:
# ['What', '=is', 'Python?']
# What-=is-Python?

# %%
prompt="wahat is Python?"
token=prompt.split(" ")
print(token)

sentence="-".join(token)
print(sentence)
# Out:
# ['wahat', 'is', 'Python?']
# wahat-is-Python?

# %% [markdown]
# ##formatted string

# %%
name="Prothoma"
age=16
height=5.234567
info=f"name {name.upper()}.Age {age}. Height {height:.2}"
print(info)

model_acc=0.5678
print(f"the model acc is {model_acc:.2%}")
# Out:
# name PROTHOMA.Age 16. Height 5.2
# the model acc is 56.78%

# %% [markdown]
# ##lsit_mutable

# %%
num=[12,344,7,8,6,654,23]
#acess
num[2]=500
print(num[2])
# new_list=num[0:3]
print(new_list)
# Out:
# 500
# [12, 344, 500]

# %%
##ad
num.append(1000)
# print(num)

num.insert(0,15)
# print(num)


#delete
num.pop()
num.remove(500)
print(num)
# Out:
# [15, 15, 15, 12, 344, 8, 6, 654, 23]

# %%
num=[10,30,12,5,6,4,3]
foat_num=[1.7,2.9,7.0,9.0]
fruits=['apple','orangr']
mix=[2,'apple',33.5]
list2d=[[2,3,4,5],[3,4,7,9,9]]
print(list2d[0][2])
# Out:
# 4

# %%
num.sort()
print(num)
num.reverse()

print(num)
# Out:
# [3, 4, 5, 6, 10, 12, 30]
# [30, 12, 10, 6, 5, 4, 3]

# %% [markdown]
# ##stack and list///and queue

# %%
#stack

stack=[]
stack.append(0)
stack.append(1)
stack.append(2)
stack.append(3)
stack.append(4)
print(stack)
print(stack.pop(),stack)
# Out:
# [0, 1, 2, 3, 4]
# 4 [0, 1, 2, 3]

# %%
#queue
queue=[]
queue.append(1)
queue.append(2)
queue.append(3)
queue.append(4)

print(queue)
print(queue.pop(0))

#acess
print(f"Front {queue[0]}")
print(f"top {queue[-1]}")
# Out:
# [1, 2, 3, 4]
# 1
# Front 2
# top 4

# %%
even=[]

for i in range(10):
  if i%2==0:
    even.append(i)
print(even)
# Out:
# [0, 2, 4, 6, 8]

# %%
##list comprehension
r_list=[x*2 for x in range(10) if x%2==0]
print(r_list)
# Out:
# [0, 4, 8, 12, 16]

# %%
fruits=['apple','orange','lichi']

cap_fruits=[]

for fruit in fruits:
  cap_fruits.append(fruit.capitalize())
print(cap_fruits)
# Out:
# ['Apple', 'Orange', 'Lichi']

# %%
fruits = ['APple', 'oraNge', 'licHi']

cap_fruits = [fruit.lower() for fruit in fruits]

print(cap_fruits)
# Out:
# ['apple', 'orange', 'lichi']
